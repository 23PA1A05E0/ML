# %% [markdown]
# <a href="https://colab.research.google.com/github/23PA1A05E0/ML/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASSIGNMENT - 2

# %% [markdown]
# Importing Library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #BASIC LINE PLOT

# %% [markdown]
# Plot a simple line graph of 𝑦 = 𝑥
# 2
# for 𝑥 values ranging from -10 to 10

# %%
x = np.arange(-10,11,1)
y = x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# Label the x-axis as "X Values" and the y-axis as "Squared Values."

# %%
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.plot(x,y)
plt.show()

# %% [markdown]
# o Add a title to the graph.

# %%
plt.title("Y = X^2 graph")
plt.show()

# %% [markdown]
# #2 . BAR PLOT

# %% [markdown]
# o Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi', 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].

# %%
data = {'Sai':85, 'Vamsi':90, 'Divij':78, 'Sritan':92, 'Sita':88}
names = list(data.keys())
marks = list(data.values())
plt.bar(names,marks)
plt.show()

# %% [markdown]
# o Add labels to the x-axis and y-axis and give the chart a title.

# %%
plt.title("Marks of 5 students")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.bar(names,marks)
plt.show()

# %% [markdown]
# #3.SCATTER PLOT

# %% [markdown]
# o Generate two lists of 20 random integers each (for x and y coordinates).

# %%
x = np.random.randint(1,100,20)
y = np.random.randint(1,100,20)

# %% [markdown]
# Create a scatter plot with these values, and customize it by adding color,
# size, and labels to the points.

# %%
plt.scatter(x,y,color="red",label="points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %% [markdown]
# #4. Histogram

# %% [markdown]
# o Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram.

# %%
# Simulate 100 random values from a normal distribution
data = np.random.randn(100)
plt.hist(data, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 Random Values from a Normal Distribution')

# Display the plot
plt.show()

# %% [markdown]
# o Customize the number of bins and add a grid to the plot.

# %%
# Simulate 100 random values from a normal distribution
data = np.random.randn(100)
plt.hist(data, bins=15, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 Random Values from a Normal Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# #5. Pie Chart

# %% [markdown]
# Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E']
# with values [20, 30, 25, 15, 10].
#
# Display the percentage values on the chart and use a color palette for
# differentiation.

# %%
data = {'A':20, 'B':30, 'C':25, 'D':15, 'E':10}
labels = list(data.keys())
values = list(data.values())
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #6. Box Plot (Seaborn)

# %% [markdown]
# o Create a box plot to visualize the distribution of the marks scored by
# students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].

# %%
import seaborn as sns
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
sns.boxplot(data=marks)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Box Plot of Marks Scored by Students')
# Display the plot
plt.show()

# %% [markdown]
# o Highlight the median and any outliers.

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]

sns.boxplot(data=marks)

median = np.median(marks)
plt.axhline(median, color='r', linestyle='--', label='Median')

plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Box Plot of Marks Scored by Students')

plt.legend()
plt.show()

# %% [markdown]
# #7. Heatmap (Seaborn)

# %% [markdown]
# o Create a 5x5 matrix with random integers between 1 and 10 using
# np.random.randint() and visualize it as a heatmap using Seaborn.

# %%
import seaborn as scn
matrix = np.random.randint(1,10,size=(5,5))
scn.heatmap(matrix)
# plt.show()
# Out:
# <Axes: >

# %% [markdown]
# o Add a color bar and annotate the heatmap with the values.

# %%
matrix = np.random.randint(1,10,size=(5,5))
scn.heatmap(matrix, annot=True, cmap='YlGnBu')
scn.heatmap(matrix)
# Out:
# <Axes: >

# %% [markdown]
# #8. Comparison of Matplotlib and Seaborn

# %% [markdown]
# o Generate a pair of plots (bar charts or line plots) using the same data in
# both Matplotlib and Seaborn.
#
# o Highlight the differences in the code, syntax, and aesthetics of the two
# libraries.

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C', 'D', 'E']
values = [20, 30, 25, 15, 10]
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart using Matplotlib')
# Display the plot
plt.show()

# %% [markdown]
# #Differences in Code, Syntax, and Aesthetics

# %% [markdown]
# #Code and Syntax:
# Matplotlib: The code is more straightforward and requires fewer imports. You directly use the plt.bar() function to create the bar chart.
#
# **Seaborn**: You need to create a DataFrame to use Seaborn effectively. The sns.barplot() function is used, and you pass the DataFrame along with the column names for the x and y axes.
#
# #Aesthetics:
# ***Matplotlib***: The default aesthetics are simpler and more basic. Customization requires more manual adjustments.
#
# ***Seaborn***: The default aesthetics are more polished and visually appealing. Seaborn automatically applies a more sophisticated style to the plots.

# %% [markdown]
# #9. Pair Plot (Seaborn)

# %% [markdown]
#  Manually create a small dataset with columns such as 'Age', 'Height',
# 'Weight' for 10 individuals and visualize the relationships using a pair plot

# %%
data = {
    'Age': [23, 25, 22, 24, 26, 28, 30, 21, 27, 29],
    'Height': [165, 170, 160, 175, 168, 172, 180, 158, 176, 169],
    'Weight': [60, 65, 55, 70, 62, 68, 75, 54, 72, 66]
}
df = pd.DataFrame(data)
sns.pairplot(df)
# plot
plt.suptitle('Pair Plot of Age, Height, and Weight', y=1.02)
# Display the plot
plt.show()

# %% [markdown]
# #10. Save and Style Plots

# %% [markdown]
# • Plot any graph of your choice and save it in both .png and .pdf formats.
#
# • Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain
# how the style impacts the visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Apply the 'ggplot' style
plt.style.use('ggplot')

# Generate x values
x = np.linspace(0, 10, 100)

# Compute y values
y = np.sin(x)

# Create the plot
plt.plot(x, y, label='sin(x)')

# Customize the plot
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Plot of sin(x)')
plt.legend()

# Save the plot in .png and .pdf formats
plt.savefig('plot.png')
plt.savefig('plot.pdf')

# Display the plot
plt.show()

# %% [markdown]
# ### The **'ggplot'** style is inspired by the aesthetics of the ggplot2 package in R.
#
# It provides a clean and modern look to the plots with grid lines, a light gray background, polished font and line styles, and a vibrant color palette.
